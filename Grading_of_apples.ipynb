# %% [markdown]
# <a href="https://colab.research.google.com/github/Respa583/Grading-of-Apples/blob/main/Grading_of_apples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# %pip install -qr requirements.txt  

import torch
from IPython.display import Image, clear_output  

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (Tesla K80)

# %%
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q ../APPLE.zip -d ../

# %%
# !python train.py --img 640 --batch 16 --epochs 80 --data custom_data.yaml --weights yolov5s.pt --nosave --cache
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-102-g7b863a3 torch 1.8.1+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='./data/custom_data.yaml', device='', entity=None, epochs=80, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --weights runs/train/exp3/weights/last.pt --img 640 --conf 0.50 --source ../VID_20210503_193949.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (7013/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.007s)
# video 1/1 (7014/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.009s)
# video 1/1 (7015/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.007s)
# video 1/1 (7016/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.007s)
# video 1/1 (7017/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.008s)
# video 1/1 (7018/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.007s)
# video 1/1 (7019/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.008s)
# video 1/1 (7020/12010) /content/yolov5/../VID_20210503_193949.mp4: 640x384 3 fresh_apples, Done. (0.007s)
# ...
